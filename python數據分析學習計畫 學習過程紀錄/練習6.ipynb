# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
L=[3, 6, 2, 4, 8, 4, 2]

# %%
plot(L)

# %%
G=[2, 1, 5, 0, 6, 1]

# %%
L+G
# Out:
# [3, 6, 2, 4, 8, 4, 2, 2, 1, 5, 0, 6, 1]

# %%
3*L
# Out:
# [3, 6, 2, 4, 8, 4, 2, 3, 6, 2, 4, 8, 4, 2, 3, 6, 2, 4, 8, 4, 2]
