# %% [markdown]
# # 自由作筆記

# %% [markdown]
# # 大標題
# ## 小標題
# 小標題

# %% [markdown]
# ## 分項說明
#
# * 一
# * 二

# %% [markdown]
# ## 連結
#
# [網址](https://cou05.ewant.org/mod/ewantvideo/view.php?id=26623&forceview=1)

# %% [markdown]
# ## 插入圖片
#
# ![圖](attachment:image.png)
