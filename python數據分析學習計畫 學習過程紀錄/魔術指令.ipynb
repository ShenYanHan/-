# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
plot([-2, 10, 3])

# %%
randn(10)
# Out:
# array([-0.53675921,  1.0730024 ,  0.47959948, -0.4445902 , -1.06595939,
#        -0.65060533,  0.00804772, -1.53396247, -1.01888616,  1.10974549])

# %%
plot(randn(10))

# %%
plot((randn(10)), (randn(10)))
