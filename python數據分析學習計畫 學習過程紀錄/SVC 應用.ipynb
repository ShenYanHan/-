# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[-3,2], [-6,5], [3,-4], [-2,8]])
y = np.array([1, 1, 2, 2])

# %%
plt.scatter([-3,-6,3,2], [2,5,-4,-8], c=[1, 1, 2, 2])

# %%
x
# Out:
# array([[-3,  2],
#        [-6,  5],
#        [ 3, -4],
#        [-2,  8]])

# %%
x[2, 1]
# Out:
# -4

# %%
x[:,0]
# Out:
# array([-3, -6,  3, -2])

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
x
# Out:
# array([[-3,  2],
#        [-6,  5],
#        [ 3, -4],
#        [-2,  8]])

# %%
from sklearn.svm import SVC

# %%
clf = SVC()

# %%
clf.fit(x, y)
# Out:
# SVC()

# %%
clf.predict([[-3,2]])
# Out:
# array([1])

# %%
clf.predict(x)
# Out:
# array([1, 1, 2, 2])

# %%
xx = [1,2,3,4]
yy = [5,6,7,8]

# %%
X, Y = np.meshgrid(xx,yy)

# %%
X, Y = np.meshgrid(np.linspace(-6,3,30), np.linspace(-4,8,30))

# %%
X = X.ravel()
Y = Y.ravel()

# %%
plt.scatter(X, Y)

# %%
xx = [1,2,3,4]
yy = [5,6,7,8]

# %%
list(zip(xx,yy))
# Out:
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
z = clf.predict(list(zip(X,Y)))

# %%
plt.scatter(X, Y, s=50, c=z)
